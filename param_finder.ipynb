# %%
import pandas as pd

df = pd.read_csv("mining_results.csv")

data_cols = [col for col in df.columns if col.startswith('LOSS_')]

results = []

for col in data_cols:
    # Get the 3 rows with the smallest values for the current column
    top_3_rows = df.nsmallest(3, col)
    
    # Iterate through those 3 rows to extract data
    for index, row in top_3_rows.iterrows():
        results.append({
            'Column': col,
            'Min Value': row[col],
            'id_1': row['source_db'],
            'id_2': row['trial_id']
        })

# 4. View the results
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#           Column  Min Value                      id_1  id_2
# 0   LOSS_13_hab3  11.888002          Resilient_hab.db    51
# 1   LOSS_13_hab3  14.097324          Resilient_hab.db    40
# 2   LOSS_13_hab3  14.150502          Resilient_hab.db    67
# 3   LOSS_13_def2   4.298934      Control_hab_FINAL.db    62
# 4   LOSS_13_def2   4.535491      Control_hab_FINAL.db    34
# 5   LOSS_13_def2   6.306948     Resilient_hab_FAIL.db    18
# 6   LOSS_14_hab3  11.147187          Resilient_hab.db    51
# 7   LOSS_14_hab3  13.899539          Resilient_hab.db    24
# 8   LOSS_14_hab3  16.061539          Resilient_def.db     0
# 9   LOSS_14_def2   8.542998          Resilient_hab.db    51
# 10  LOSS_14_def2  11.525233          Resilient_def.db     0
# 11  LOSS_14_def2  11.676998          Resilient_hab.db    40
# 12  LOSS_15_hab3  14.824487          Resilient_hab.db    51
# 13  LOSS_15_hab3  15.562896          Resilient_hab.db    40
# 14  LOSS_15_hab3  16.436657          Resilient_def.db     0
# 15  LOSS_15_def2  11.099953          Resilient_hab.db    51
# 16  LOSS_15_def2  11.685289          Resilient_hab.db    24
# 17  LOSS_15_def2  12.661900          Resilient_hab.db    40
# 18  LOSS_16_hab3   7.516555          Resilient_hab.db    59
# 19  LOSS_16_hab3   8.164436          Resilient_hab.db    40
# 20  LOSS_16_hab3   8.501453          Resilient_hab.db    67
# 21  LOSS_16_def2   9.939134          Resilient_hab.db    51
# 22  LOSS_16_def2  12.282878        Susceptible_def.db     2
# 23  LOSS_16_def2  13.047702          Resilient_def.db     0
# 24  LOSS_17_hab3   9.991365          Resilient_hab.db    67
# 25  LOSS_17_hab3  10.332749          avg_mouse_fit.db    31
# 26  LOSS_17_hab3  10.546604          avg_mouse_fit.db     7
# 27  LOSS_17_def2   6.958618        Susceptible_def.db     2
# 28  LOSS_17_def2   7.711196          Resilient_hab.db    58
# 29  LOSS_17_def2   9.105596          Resilient_hab.db    53
# 30  LOSS_18_hab3   2.963608     Resilient_hab_FAIL.db    18
# 31  LOSS_18_hab3   3.859679          avg_mouse_fit.db     7
# 32  LOSS_18_hab3   3.929171      Control_hab_FINAL.db    62
# 33  LOSS_18_def2   5.498350          Resilient_hab.db    24
# 34  LOSS_18_def2   7.250524          Resilient_hab.db    83
# 35  LOSS_18_def2   7.719489      Control_hab_FINAL.db    34
# 36  LOSS_19_hab3   3.585350          Resilient_hab.db    24
# 37  LOSS_19_hab3   4.545758      Control_hab_FINAL.db    34
# 38  LOSS_19_hab3   5.170999      Control_hab_FINAL.db    62
# 39  LOSS_19_def2   5.394433          avg_mouse_fit.db     7
# 40  LOSS_19_def2   6.192134          Resilient_hab.db    24
# 41  LOSS_19_def2   7.081312          Resilient_hab.db    37
# 42  LOSS_20_hab3   1.343337      Control_hab_FINAL.db    62
# 43  LOSS_20_hab3   2.287159     Resilient_hab_FAIL.db    18
# 44  LOSS_20_hab3   2.497670      Control_hab_FINAL.db    34
# 45  LOSS_20_def2   0.508551          avg_mouse_fit.db    30
# 46  LOSS_20_def2   2.424231     Resilient_hab_FAIL.db    75
# 47  LOSS_20_def2   2.569736  Susceptible_hab_FINAL.db    92

# %%
results_df.to_csv("lowest_losses.csv")

# %%
results_df.
